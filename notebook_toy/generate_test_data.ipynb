# %%
import boto3
import pandas as pd

AWS_PROD_ACCESS_KEY = "AKIAV3CMPTUBHDFPVWGR"
AWS_PROD_SECRET_ACCESS_KEY = "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"


s3_client=boto3.client(
    's3',
    aws_access_key_id=AWS_PROD_ACCESS_KEY,
    aws_secret_access_key=AWS_PROD_SECRET_ACCESS_KEY
)

# %%
import json
import os
import orjson
import shutil
import numpy as np
nodes = []

results = []
paginator = s3_client.get_paginator('list_objects_v2')
response_iterator = paginator.paginate(
    Bucket='meshkorea-fulfillment-data',
    Prefix='matnet_input_sampling_30_60/'
)
count=0
for page in response_iterator:
    for content in page['Contents']:
        train_path = '/data/'+content['Key']
        test_path = '/data/test_data/'+content['Key']
        if os.path.exists(train_path):
            continue
        try:
            s3_client.download_file('meshkorea-fulfillment-data', content['Key'], test_path)
            with open(test_path) as f:
                tmp = np.array(orjson.loads(f.read())['durations'])
            if (tmp>1e4).sum()!=0:
                os.remove(test_path)
            if count%100==0:
                print(test_path)
            count+=1
            #print(count)
        except Exception as e:
            print(e)
            print(content)
# Out:
# /data/test_data/matnet_input_sampling_30_60/100006.json
# /data/test_data/matnet_input_sampling_30_60/100822.json
# /data/test_data/matnet_input_sampling_30_60/101651.json
# /data/test_data/matnet_input_sampling_30_60/102323.json
# /data/test_data/matnet_input_sampling_30_60/103311.json
# /data/test_data/matnet_input_sampling_30_60/104058.json
# /data/test_data/matnet_input_sampling_30_60/104714.json
# /data/test_data/matnet_input_sampling_30_60/10538.json
# /data/test_data/matnet_input_sampling_30_60/106248.json
# /data/test_data/matnet_input_sampling_30_60/107014.json
# /data/test_data/matnet_input_sampling_30_60/107798.json
# /data/test_data/matnet_input_sampling_30_60/108533.json
# /data/test_data/matnet_input_sampling_30_60/109332.json
# /data/test_data/matnet_input_sampling_30_60/110020.json
# /data/test_data/matnet_input_sampling_30_60/110671.json
# /data/test_data/matnet_input_sampling_30_60/111357.json
# /data/test_data/matnet_input_sampling_30_60/112161.json
# ...
